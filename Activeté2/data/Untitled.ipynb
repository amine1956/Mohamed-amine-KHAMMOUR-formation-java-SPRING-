# %%
import sklearn
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
path="finalData.xlsx"
dl=pd.read_excel(path)
# Out:
#        Unnamed: 0  Fuel type  Brand  Model  Boite à vitesse  Origine  \
# 0               0          0     43     40                0        0
# 1               1          0     14    198                1        3
# 2               2          0     21    359                1        3
# 3               3          0     43    281                0        3
# 4               4          0     43    273                0        3
# ...           ...        ...    ...    ...              ...      ...
# 51129       51129          0     48    776                1        2
# 51130       51130          0     48    776                1        3
# 51131       51131          0     48    776                1        2
# 51132       51132          0     48    776                1        3
# 51133       51133          1     35    776                1        2
#
#        Première main  Sector  Nombre de portes   Price   Mileage  Model Year  \
# ...

# %%
del dl['Unnamed: 0']
dl
# Out:
#        Fuel type  Brand  Model  Boite à vitesse  Origine  Première main  \
# 0              0     43     40                0        0              0
# 1              0     14    198                1        3              1
# 2              0     21    359                1        3              0
# 3              0     43    281                0        3              0
# 4              0     43    273                0        3              0
# ...          ...    ...    ...              ...      ...            ...
# 51129          0     48    776                1        2              0
# 51130          0     48    776                1        3              0
# 51131          0     48    776                1        2              0
# 51132          0     48    776                1        3              0
# 51133          1     35    776                1        2              0
#
#        Sector  Nombre de portes   Price   Mileage  Model Year  Fiscal power
# ...

# %%
plt.figure(figsize=(100, 6))
dl1 = pd.DataFrame(dl.groupby(['Boite à vitesse'])['Price'].mean().sort_values(ascending = False))
dl1.plot.bar()
plt.title('boit a vitees  vs Average Price')
plt.show()
